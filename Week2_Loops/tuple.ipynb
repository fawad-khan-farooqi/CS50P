# %% [markdown]
# # Tuple
# - A tuple is a collection which is ordered and unchangeable.
# - Tuples are written with round brackets.
# ## Tuple Items
# - Tuple items are ordered, unchangeable, and allow duplicate values.
# - Tuple items are indexed, the first item has index [0], the second item has index [1] etc.
# ## Ordered
# - When we say that tuples are ordered, it means that the items have a defined order, and that order will not change.
# ## Unchangeable
# - Tuples are unchangeable, meaning that we cannot change, add or remove items after the tuple has been created.
# ## Allow Duplicates
# - Since tuples are indexed, they can have items with the same value:

# %%
import sys

coordinates = (-4709,123153) #() is used to create a tuple
latitude, longitude = coordinates # unpacking
print(coordinates) #printing as a whole
print(coordinates[0], coordinates[1]) #printing by accessing each element one by one



coordinateslist = [-4709,123153]

# tuple is usually memory efficient than list
print(f"tuple size: {sys.getsizeof(coordinates)} \n List size: {sys.getsizeof(coordinateslist)} ")

# coordinates[0] = 5 will gives error as tuple is immutable
# Out:
# (-4709, 123153)
# -4709 123153
# tuple size: 64
#  List size: 72
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 12
#       8
#       9
#      10 coordinateslist = [-4709,123153]
#      11 print(f"tuple size: {sys.getsizeof(coordinates)} \n List size: {sys.getsizeof(coordinateslist)} ")
# ---> 12 coordinates[0] = 5
#
# TypeError: 'tuple' object does not support item assignment
