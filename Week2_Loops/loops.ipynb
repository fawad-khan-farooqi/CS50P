# %% [markdown]
# # Python has two primitive loop commands:
# - while loops
# - for loops
#
# # The while Loop
# - With the while loop we can execute a set of statements as long as a condition is true.
#
# # The break Statement
# - With the break statement we can stop the loop even if the while condition is true

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %% [markdown]
# # The continue Statement
# - With the continue statement we can stop the current iteration, and continue with the next:

# %%
i = 0
while i < 6:
    i+=1
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# #Note
# -Ctrl + C in terminal to cancel or interupt

# %%
i = 0
while i < 3:
    print("hello")
    i+=1
# Out:
# hello
# hello
# hello

# %% [markdown]
# # The else Statement
# - With the else statement we can run a block of code once when the condition no longer is true
# - The else block will NOT be executed if the loop is stopped by a break statement.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")

# %% [markdown]
# # For Loops
# - A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
# - With the for loop we can execute a set of statements, once for each item in a list, tuple, set etc.

# %%
for i in [0,1,2]:
    print("hello")
# Out:
# hello
# hello
# hello

# %%
for i in [0,1,2]:
    print(i)
# Out:
# 0
# 1
# 2

# %%
for _ in range(3):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# # Looping Through a String
# - Even strings are iterable objects, they contain a sequence of characters:

# %%
for x in "Ahmad":
  print(x, end="\t")
# Out:
# A	h	m	a	d

# %% [markdown]
# # The break Statement
# - With the break statement we can stop the loop before it has looped through all the items:

# %%
for x in "Ahmad":
    if x == "m":
        break
    print(x, end=" ")
# Out:
# A h

# %% [markdown]
# # The continue Statement
# - With the continue statement we can stop the current iteration of the loop, and continue with the next:

# %%
for x in "Tom Cruise":
    if x == "i":
        continue
    print(x, end=" ")
# Out:
# T o m   C r u s e

# %% [markdown]
# # The range() Function
# - To loop through a set of code a specified number of times, we can use the range() function,
# - The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and ends at a specified number.
# - Note that range(6) is not the values of 0 to 6, but the values 0 to 5
# - The range() function defaults to 0 as a starting value, however it is possible to specify the starting value by adding a parameter: range(2, 6), which means values from 2 to 6 (but not including 6)
# - The range() function defaults to increment the sequence by 1, however it is possible to specify the increment value by adding a third parameter: range(1, 10, 2)

# %%
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(1, 10, 2):
    print(x)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # Else in For Loop
# - The else keyword in a for loop specifies a block of code to be executed when the loop is finished
# - The else block will NOT be executed if the loop is stopped by a break statement.

# %%
for x in range(3):
    print(x)
else:
    print("loop is over")
# Out:
# 0
# 1
# 2
# loop is over

# %%
for x in range(3):
    print(x)
    if x == 2: 
        break
else:
    print("loop is over")
# Out:
# 0
# 1
# 2

# %% [markdown]
# # Nested Loops
# - A nested loop is a loop inside a loop.
# - The "inner loop" will be executed one time for each iteration of the "outer loop":

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
    for y in fruits:
        print(x, y, end=" ")
    print()
# Out:
# red apple red banana red cherry
# big apple big banana big cherry
# tasty apple tasty banana tasty cherry

# %% [markdown]
# # The pass Statement
# - for loops cannot be empty, but if you for some reason have a for loop with no content, put in the pass statement to avoid getting an error.

# %%
for x in range(3):
    pass

# %%
print("hello\n" * 3, end=" ")
# Out:
# hello
# hello
# hello

# %%
while True:
    n = int(input("what's the number"))
    if n > 0:
        break
for _ in range(n):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
def main():
    number = get_number()
    hello(number)

def get_number():
    while True:
        n = int(input("What's the number? "))
        if n>0:
            return n

def hello(x):
    for _ in range(x):
        print("Hello")
    
main()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %% [markdown]
# Lists

# %%
students = ["Ali", "Ahmad", "Amjad"]

print(students[0])
print(students[1])
print(students[2])

print (students) # entire list
# Out:
# Ali
# Ahmad
# Amjad
# ['Ali', 'Ahmad', 'Amjad']

# %%
students = ["Ali", "Ahmad", "Amjad"]

for student in students:
    print(student)
# Out:
# Ali
# Ahmad
# Amjad

# %% [markdown]
# # print the list with their positions by using len()

# %%
students = ["Ali", "Ahmad", "Amjad"]

for i in range(len(students)):
    print(i+1, students[i], sep=". ")
# Out:
# 1. Ali
# 2. Ahmad
# 3. Amjad

# %% [markdown]
# # Dictionaries

# %%
students = {
    "Ali": "Islamabad",
    "Ahmad": "Abbottabad",
    "Amjad": "Peshawar"
}

for student in students:
    #print(student) this will print only keys as it works differently from lists, and student has Key
    #print(students[student]) this will print the citys
    #print(students) it will print entire dictionary
    #we want to print both i.e. key and its associated city, but in one line
    print(f"{student} lives in {students[student]}")
# Out:
# Ali lives in Islamabad
# Ahmad lives in Abbottabad
# Amjad lives in Peshawar

# %% [markdown]
# # list of dictionaries to associate more than one value with a key
# # Note
# - Python has a special None designation where there is no value associated with a key.

# %%
# create a list of dicts. 
# The list called students has four dicts within it:
# One for each student. 

students = [ #list
    {"name":"Ahmad", "city":"Abbottabad", "province":"KPK"}, #an item of list, A dictionary
     {"name":"Ali", "city":"Islamabad", "province":None},
    {"name":"Amjad", "city":"Peshawar", "province":"KPK"}
]

for student in students:
    #print(student) student will store the dictionary (as the item of the list)
    print(f"{student["name"]} lives in {student["city"]}, {student["province"]}")
# Out:
# Ahmad lives in Abbottabad, KPK
# Ali lives in Islamabad, None
# Amjad lives in Peshawar, KPK

# %% [markdown]
# # mario bricks
# - print three hashes

# %%
#one way
for _ in range(3):
   print("#")
# Out:
# #
# #
# #

# %%
print("#\n" * 3, end="")
# Out:
# #
# #
# #

# %% [markdown]
# # printing column and rows of mario by using functions

# %%
def main():
    print_col(3)
    print_row(4)

def print_col(h):
    print("#\n" * h, end="")

def print_row(w):
    print("? " * w, end="")
main()
# Out:
# #
# #
# #
# ? ? ? ?

# %% [markdown]
# # printing square of size n

# %%
def main():
    print_square(3)

def print_square(n):
    for i in range(n):
        print("#"*3)

main()
# Out:
# ###
# ###
# ###

# %% [markdown]
# - by using nested loops

# %%
def main():
    print_square(3)

def print_square(n):
    # for each row in square
    for i in range(n):
        # for each brick in the row
        for j in range(n):
            # print brick
            print("#", end="")
        # add a line after printing a row
        print() 

main()
# Out:
# ###
# ###
# ###
